# %% [markdown]
# turns out pytorch does not support python versions > 3.9 worked as intended after downgrading to python 3.8
#
# 파이썬 버전 변경

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
# !wget https://www.python.org/ftp/python/3.8.0/Python-3.8.0.tgz
# !tar xvfz Python-3.8.0.tgz
# !Python-3.8.0/configure
# !make
# !sudo make install

# %%
# !python --version
# Out:
# Python 3.8.0

# %%
#git install시 나오는 command errored out with exit status 1 python setup.py egg_info 오류 해결 - 셋업 툴 업데이트
pip install --upgrade setuptools
# Out:
# ...
#      |████████████████████████████████| 1.3MB 2.0MB/s
# ...
#   Found existing installation: setuptools 41.2.0
#     Uninstalling setuptools-41.2.0:
#       Successfully uninstalled setuptools-41.2.0
# ...

# %%
# !pip install pandas==1.3.3
# Out:
# ...
#      |████████████████████████████████| 4.7MB 3.1MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
# ERROR: Command errored out with exit status 1: /usr/local/bin/python3.8 /usr/local/lib/python3.8/site-packages/pip/_vendor/pep517/_in_process.py get_requires_for_build_wheel /tmp/tmp3fsch704 Check the logs for full command output.

# %%
# !pip install git+https://github.com/SKT-AI/KoBART#egg=kobart
# Out:
# ...
#   Cloning https://github.com/SKT-AI/KoBART to /tmp/pip-install-k5xy3sgh/kobart
#   Running command git clone -q https://github.com/SKT-AI/KoBART /tmp/pip-install-k5xy3sgh/kobart
# ...
#   Using cached https://files.pythonhosted.org/packages/4f/3f/dc04c5031581cb55e178e7305ad32fe1ecfa8691fa1092c09f772c44f81c/boto3-1.35.15-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/b1/a7/824332581e258b5aa4f3763ecb2a797e5f9a54269044ba2e50ac19936b32/pandas-2.0.3.tar.gz
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
# ERROR: Command errored out with exit status 1: /usr/local/bin/python3.8 /usr/local/lib/python3.8/site-packages/pip/_vendor/pep517/_in_process.py get_requires_for_build_wheel /tmp/tmpmxaoe0es Check the logs for full command output.

# %%
from kobart import get_kobart_tokenizer
kobart_tokenizer = get_kobart_tokenizer()
kobart_tokenizer.tokenize("안녕하세요. 한국어 BART 입니다.🤣:)l^o")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-47657b670c42> in <cell line: 1>()
# ----> 1 from kobart import get_kobart_tokenizer
#       2 kobart_tokenizer = get_kobart_tokenizer()
#       3 kobart_tokenizer.tokenize("안녕하세요. 한국어 BART 입니다.🤣:)l^o")
#
# ModuleNotFoundError: No module named 'kobart'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
